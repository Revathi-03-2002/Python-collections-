# %% [markdown]
# <a href="https://colab.research.google.com/github/Revathi-03-2002/Python-collections-/blob/main/python_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
name = "Python"

name = "J" + name[1:]

print(name)
# Out:
# Jython

# %%
name="revathi"
print(name.lower())
# Out:
# revathi

# %%
name="revathi"
print(name.upper())
# Out:
# REVATHI

# %%
name="revathi"
print(name.capitalize())
# Out:
# Revathi

# %%
name="revathi poots"
print(name.strip())
# Out:
# revathi poots

# %%
text="my name is revathi"
print(text.replace("revathi","poots"))
# Out:
# my name is poots

# %%
name="madhumitha"
print(name.count("a"))
# Out:
# 2

# %%
fruits="apple"
print(fruits.find("p"))
# Out:
# 1

# %%
name="revathi"
age=25
print(f"my name is {name} and i am {age} years old.")
# Out:
# my name is revathi and i am 25 years old.

# %%
student="jegaa"
mark=100
print(f"{student} scored {mark} marks.")
# Out:
# jegaa scored 100 marks.

# %%
name="revathi"
age=30
print("my name is {} and i am {}.".format(name,age))
# Out:
# my name is revathi and i am 30.

# %%
#variables
name="revathi"
age="24"
city="coimbatore"
print(name)
print(age)
print(city)
# Out:
# revathi
# 24
# coimbatore

# %%
#print function
name = "Revathi"
age = 25
mark = 85.5
passed = True

print(name)
print(age)
print(mark)
print(passed)
# Out:
# Revathi
# 25
# 85.5
# True

# %%
#input from user
#get name from user

name=input("enter a name:")
print("hello",name)
# Out:
# enter a name:revathi
# hello revathi

# %%
#get age from user
age=input("enter your age:")
print("my age is",age)
# Out:
# enter your age:25
# my age is 25

# %%
#get's student name and mark
name=input("enter student name:")
mark=int(input("enter student mark:"))
print("student:" ,name)
print("student:", mark)
# Out:
# enter student name:madhu
# enter student mark:90
# student: madhu
# student: 90

# %%
#data types
#iteger
age = 25
students = 60
marks = 90
print(age)
print(students)
print(marks)
# Out:
# 25
# 60
# 90

# %%
#float
height = 5.6
price = 99.50
percentage = 87.5
print(height)
print(price)
print(percentage)
# Out:
# 5.6
# 99.5
# 87.5

# %%
#string
name = "Revathi"
college = "KGISL"
subject = "Python"
print(name)
print(college)
print(subject)
# Out:
# Revathi
# KGISL
# Python

# %%
#boolean
is_student = True
is_present = False
print(is_student)
print(is_present)
# Out:
# True
# False

# %%
#find data type
name = "Revathi"
mark = 85.5
passed = True
print(type(name))
print(type(mark))
print(type(passed))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
#type conversion
#string to integer
age = int(input("Enter your age: "))
print(age)
print(type(age))
# Out:
# Enter your age: 24
# 24
# <class 'int'>

# %%
#string to float
price = input("Enter the price: ")
price = float(price)
print(price)
print(type(price))
# Out:
# Enter the price: 60
# 60.0
# <class 'float'>

# %%
#integer to float
marks = 80
marks = float(marks)
print(marks)
# Out:
# 80.0

# %%
#float to integer
price = 99.75
price = int(price)
print(price)
# Out:
# 99

# %%
#integer to string
number = 100
number = str(number)
print(number)
print(type(number))
# Out:
# 100
# <class 'str'>
